# %%
import pandas as pd

# %%
df = pd.read_csv("agra_potato.csv")
df.head()
# Out:
#   Min,Max,Modal Price from Uttar Pradesh,Agra[Potato],Agra from 01-Jan-2020To31-Dec-2020 (Total-285) (Total-285)  \
# 0                                             Sl no.
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#       Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  District Name  Market Name  Commodity    Variety      Grade
# 1           Agra         Agra     Potato       Desi        FAQ
# 2           Agra         Agra     Potato       Desi        FAQ
# 3           Agra         Agra     Potato       Desi        FAQ
# 4           Agra         Agra     Potato       Desi        FAQ
#
#                 Unnamed: 6               Unnamed: 7  \
# 0  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)
# 1                      800                     1100
# ...
